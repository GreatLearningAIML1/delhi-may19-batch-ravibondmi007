# %% [markdown]
# ### Build a DNN using Keras with `RELU` and `ADAM`

# %% [markdown]
# #### Load tensorflow

# %%
from tensorflow import keras
from tensorflow.keras import models, backend
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Reshape, Dropout

# %% [markdown]
# #### Collect Fashion mnist data from tf.keras.datasets

# %%
(xTrain, yTrain), (xTest, yTest) = mnist.load_data()

print(xTrain.shape)
print(xTest.shape)
print(yTrain.shape)
print(yTest.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# (60000,)
# (10000,)

# %% [markdown]
# #### Change train and test labels into one-hot vectors

# %%
print(yTrain.shape)
print(yTest.shape)

yTrain = keras.utils.to_categorical(yTrain)
yTest = keras.utils.to_categorical(yTest)

print(yTrain.shape)
print(yTest.shape)
# Out:
# (60000,)
# (10000,)
# (60000, 10)
# (10000, 10)

# %% [markdown]
# #### Build the Graph

# %% [markdown]
# #### Initialize model, reshape & normalize data

# %%
"""
NORMALIZE DATA:
---------------

As the value ranges from 0 to 255, therefore, normalize by dividing each value by 255.



---***---



NOTE:
min-max scaler value = (value - min)/(max-min)

In above replacing min with 0 and max with 255 gives:
SCALED VALUE = value/max
"""

xTrain = xTrain/255
xTest = xTest/255

"""
RESHAPE DATA:
------------
"""

print("Shape before reshaping: ", xTrain.shape)

xTrain = xTrain.reshape(xTrain.shape[0], 28, 28, 1)
xTest = xTest.reshape(xTest.shape[0], 28, 28, 1)

print("Shape after reshaping:  ", xTrain.shape)
# Out:
# Shape before reshaping:  (60000, 28, 28)
# Shape after reshaping:   (60000, 28, 28, 1)

# %%
TRAIN = False
BATCH_SIZE = 32
EPOCHS = 20

# %%
#Clear out tensorflow memory
backend.clear_session()


"""
INITIALIZE MODEL:
-----------------
"""
# Define the Type of Model
model1 = Sequential()


"""
RESHAPE DATA:
-------------
"""
# Input Layer: Flatten Imgaes to Vector
model1.add(Reshape((784,), input_shape=(28, 28, 1)))

# %% [markdown]
# #### Add two fully connected layers with 200 and 100 neurons respectively with `relu` activations. Add a dropout layer with `p=0.25`

# %%
# Hidden Layer 1
model1.add(keras.layers.BatchNormalization())
model1.add(Dense(200, kernel_initializer="he_normal", use_bias=True, activation='relu'))

# Dropout
model1.add(Dropout(0.25))

# Hidden Layer 1
model1.add(keras.layers.BatchNormalization())
model1.add(Dense(100, kernel_initializer="he_normal", use_bias=True, activation='relu'))

# Dropout
model1.add(Dropout(0.25))

# %% [markdown]
# ### Add the output layer with a fully connected layer with 10 neurons with `softmax` activation. Use `categorical_crossentropy` loss and `adam` optimizer and train the network. And, report the final validation.

# %%
# Output Layer
model1.add(Dense(units=10, kernel_initializer='he_normal', use_bias=True, activation="softmax"))

# Loss and Optimizer
adam_optimizer = keras.optimizers.Adam(learning_rate=0.02)
# sgd_optimizer = keras.optimizers.SGD()
model1.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Store Training Results
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='auto')
callback_list = [early_stopping]# [stats, early_stopping]

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 784)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 784)               3136
# _________________________________________________________________
# dense (Dense)                (None, 200)               157000
# _________________________________________________________________
# dropout (Dropout)            (None, 200)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 200)               800
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1010
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                110
# =================================================================
# Total params: 182,376
# Trainable params: 180,408
# Non-trainable params: 1,968
# _________________________________________________________________

# %%
# Train the model
model1.fit(xTrain, yTrain, epochs=EPOCHS, batch_size=BATCH_SIZE,
           validation_data=(xTest, yTest), 
           callbacks=callback_list, 
           verbose=True
          )
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 11s 179us/sample - loss: 1.1881 - acc: 0.7765 - val_loss: 0.5849 - val_acc: 0.8899
# Epoch 2/20
# 60000/60000 [==============================] - 10s 168us/sample - loss: 0.4464 - acc: 0.8819 - val_loss: 0.3405 - val_acc: 0.8887
# Epoch 3/20
# 60000/60000 [==============================] - 10s 174us/sample - loss: 0.3326 - acc: 0.8826 - val_loss: 0.2843 - val_acc: 0.8912
# Epoch 4/20
# 60000/60000 [==============================] - 10s 170us/sample - loss: 0.3061 - acc: 0.8832 - val_loss: 0.2789 - val_acc: 0.8907
# Epoch 5/20
# 60000/60000 [==============================] - 10s 171us/sample - loss: 0.2867 - acc: 0.8839 - val_loss: 0.2593 - val_acc: 0.8912
# Epoch 6/20
# 60000/60000 [==============================] - 10s 169us/sample - loss: 0.2833 - acc: 0.8840 - val_loss: 0.2531 - val_acc: 0.8907
# Epoch 7/20
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.2642 - acc: 0.8885 - val_loss: 0.2459 - val_acc: 0.8947
# Epoch 8/20
# 60000/60000 [==============================] - 10s 172us/sample - loss: 0.2621 - acc: 0.8878 - val_loss: 0.2349 - val_acc: 0.8962
# Epoch 9/20
# 60000/60000 [==============================] - 11s 176us/sample - loss: 0.2167 - acc: 0.9419 - val_loss: 0.1482 - val_acc: 0.9768
# Epoch 10/20
# 60000/60000 [==============================] - 11s 179us/sample - loss: 0.1480 - acc: 0.9719 - val_loss: 0.1289 - val_acc: 0.9772
# Epoch 11/20
# 60000/60000 [==============================] - 11s 177us/sample - loss: 0.1371 - acc: 0.9726 - val_loss: 0.1166 - val_acc: 0.9797
# Epoch 12/20
# 60000/60000 [==============================] - 11s 175us/sample - loss: 0.1318 - acc: 0.9728 - val_loss: 0.1221 - val_acc: 0.9772
# Epoch 13/20
# 60000/60000 [==============================] - 10s 172us/sample - loss: 0.1208 - acc: 0.9739 - val_loss: 0.1195 - val_acc: 0.9774
# Epoch 14/20
# 60000/60000 [==============================] - 10s 172us/sample - loss: 0.1173 - acc: 0.9750 - val_loss: 0.1113 - val_acc: 0.9784
# Epoch 15/20
# 60000/60000 [==============================] - 10s 174us/sample - loss: 0.1201 - acc: 0.9734 - val_loss: 0.1176 - val_acc: 0.9773
# Epoch 16/20
# 60000/60000 [==============================] - 11s 175us/sample - loss: 0.1133 - acc: 0.9750 - val_loss: 0.1116 - val_acc: 0.9786
# Epoch 17/20
# 60000/60000 [==============================] - 10s 172us/sample - loss: 0.1146 - acc: 0.9753 - val_loss: 0.1039 - val_acc: 0.9797
# Epoch 18/20
# 60000/60000 [==============================] - 10s 174us/sample - loss: 0.1099 - acc: 0.9761 - val_loss: 0.1019 - val_acc: 0.9795
# Epoch 19/20
# 60000/60000 [==============================] - 10s 173us/sample - loss: 0.1048 - acc: 0.9774 - val_loss: 0.1059 - val_acc: 0.9803
# Epoch 20/20
# 60000/60000 [==============================] - 10s 174us/sample - loss: 0.1031 - acc: 0.9772 - val_loss: 0.1051 - val_acc: 0.9789
